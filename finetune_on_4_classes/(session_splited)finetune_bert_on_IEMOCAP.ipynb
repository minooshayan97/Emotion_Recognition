# %%
# !pip install transformers datasets evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 58.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.10.0-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 47.8 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 13.1 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 107.6 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 15.0 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2023.1.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: tokenizers, xxhash, urllib3, multiprocess, responses, huggingface-hub, transformers, datasets, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.10.0 evaluate-0.4.0 huggingface-hub-0.12.1 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.26.1 urllib3-1.26.14 xxhash-3.2.0

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.10-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.25.1)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (7.1.2)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.15.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=e1ab7cc1e24098cd3ff695b006925d98c7e3f3256b40e1c094e9d76671696d63
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.15.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.10

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset

dataset = load_dataset("minoosh/IEMOCAP_Text")
# Out:
# Downloading readme:   0%|          | 0.00/753 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/minoosh___parquet/minoosh--IEMOCAP_Text-8b3962ea9075930e/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/39.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/51.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/44.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.5k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating Session2 split:   0%|          | 0/1023 [00:00<?, ? examples/s]
# Generating Session4 split:   0%|          | 0/1031 [00:00<?, ? examples/s]
# Generating Session5 split:   0%|          | 0/1241 [00:00<?, ? examples/s]
# Generating Session3 split:   0%|          | 0/1151 [00:00<?, ? examples/s]
# Generating Session1 split:   0%|          | 0/1085 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/minoosh___parquet/minoosh--IEMOCAP_Text-8b3962ea9075930e/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     Session2: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1023
#     })
#     Session4: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1031
#     })
#     Session5: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1241
#     })
#     Session3: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1151
#     })
#     Session1: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1085
#     })
# })

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
    return tokenizer(examples["transcription"], truncation=True)

# %%
tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/1023 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1031 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1241 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1151 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1085 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
import evaluate

accuracy = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
import numpy as np

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
dataset = dataset.rename_column("emotion", "label")

# %%
labels = dataset["Session1"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

id2label["1"]
# Out:
# 'hap'

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased", num_labels=4, id2label=id2label, label2id=label2id
)
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenized_dataset = tokenized_dataset.rename_column("emotion", "label")

# %%
import torch
train_dataset = torch.utils.data.ConcatDataset([tokenized_dataset['Session1'], tokenized_dataset['Session2'], tokenized_dataset['Session3']])

# %%
train_dataset

# %%
'''splited_tokenized_dataset = tokenized_dataset['train'].train_test_split(test_size=0.2)
splited_tokenized_dataset'''
# Out:
# "splited_tokenized_dataset = tokenized_dataset['train'].train_test_split(test_size=0.2)\nsplited_tokenized_dataset"

# %%
batch_size = 16

training_args = TrainingArguments(
    output_dir="finetuned_bert-base-uncased",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=15,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
    report_to='wandb',
    run_name='finetune_bert_base_on_IEMOCAP_text'
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=tokenized_dataset["Session4"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# Cloning https://huggingface.co/minoosh/finetuned_bert-base-uncased into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/minoosh/finetuned_bert-base-uncased into local empty directory.
# Download file pytorch_model.bin:   0%|          | 17.4k/418M [00:00<?, ?B/s]
# Download file runs/Feb08_12-04-49_f873344109b0/events.out.tfevents.1675857989.f873344109b0.656.0: 100%|#######…
# Download file runs/Feb08_14-15-00_144a3875a8da/events.out.tfevents.1675865810.144a3875a8da.224.0: 100%|#######…
# Download file runs/Feb08_10-12-51_f339a4904974/events.out.tfevents.1675851181.f339a4904974.5840.0: 100%|######…
# Download file runs/Feb08_10-12-51_f339a4904974/1675851181.5398304/events.out.tfevents.1675851181.f339a4904974.…
# Download file runs/Feb08_10-43-45_18b2d2006935/events.out.tfevents.1675853140.18b2d2006935.276.0: 100%|#######…
# Download file runs/Feb08_10-43-45_18b2d2006935/1675853140.1672206/events.out.tfevents.1675853140.18b2d2006935.…
# Download file runs/Feb08_12-04-49_f873344109b0/1675857989.3221283/events.out.tfevents.1675857989.f873344109b0.…
# Download file runs/Feb08_14-15-00_144a3875a8da/1675865810.3426144/events.out.tfevents.1675865810.144a3875a8da.…
# Clean file runs/Feb08_10-12-51_f339a4904974/events.out.tfevents.1675851181.f339a4904974.5840.0:  12%|#1       …
# Clean file runs/Feb08_10-12-51_f339a4904974/1675851181.5398304/events.out.tfevents.1675851181.f339a4904974.584…
# Clean file runs/Feb08_12-04-49_f873344109b0/events.out.tfevents.1675857989.f873344109b0.656.0:   5%|4         …
# Clean file runs/Feb08_14-15-00_144a3875a8da/events.out.tfevents.1675865810.144a3875a8da.224.0:   7%|7         …
# Clean file runs/Feb08_10-43-45_18b2d2006935/events.out.tfevents.1675853140.18b2d2006935.276.0:   5%|5         …
# Clean file runs/Feb08_12-04-49_f873344109b0/1675857989.3221283/events.out.tfevents.1675857989.f873344109b0.656…
# Clean file runs/Feb08_10-43-45_18b2d2006935/1675853140.1672206/events.out.tfevents.1675853140.18b2d2006935.276…
# Clean file runs/Feb08_14-15-00_144a3875a8da/1675865810.3426144/events.out.tfevents.1675865810.144a3875a8da.224…
# Download file runs/Feb25_10-04-17_13449c46355a/events.out.tfevents.1677319478.13449c46355a.897.0: 100%|#######…
# Clean file runs/Feb25_10-04-17_13449c46355a/events.out.tfevents.1677319478.13449c46355a.897.0:  22%|##2       …
# Download file training_args.bin: 100%|##########| 3.50k/3.50k [00:00<?, ?B/s]
# Download file runs/Feb25_10-04-17_13449c46355a/1677319478.418264/events.out.tfevents.1677319478.13449c46355a.8…
# Clean file training_args.bin:  29%|##8       | 1.00k/3.50k [00:00<?, ?B/s]
# Clean file runs/Feb25_10-04-17_13449c46355a/1677319478.418264/events.out.tfevents.1677319478.13449c46355a.897.…
# Clean file pytorch_model.bin:   0%|          | 1.00k/418M [00:00<?, ?B/s]

# %%
import torch
torch.cuda.empty_cache()

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3259
#   Num Epochs = 15
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3060
#   Number of trainable parameters = 109485316
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: minooshayan97 (minoosh). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230225_120213-hbiaymzq</code>
# Syncing run <strong><a href='https://wandb.ai/minoosh/huggingface/runs/hbiaymzq' target="_blank">finetune_bert_base_on_IEMOCAP_text</a></strong> to <a href='https://wandb.ai/minoosh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/minoosh/huggingface' target="_blank">https://wandb.ai/minoosh/huggingface</a>
#  View run at <a href='https://wandb.ai/minoosh/huggingface/runs/hbiaymzq' target="_blank">https://wandb.ai/minoosh/huggingface/runs/hbiaymzq</a>
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3060' max='3060' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3060/3060 15:58, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.966995</td>
#       <td>0.605238</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.889896</td>
#       <td>0.673133</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.847600</td>
#       <td>0.928346</td>
#       <td>0.672163</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.847600</td>
#       <td>1.010998</td>
#       <td>0.682832</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.341900</td>
#       <td>1.094706</td>
#       <td>0.674103</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.341900</td>
#       <td>1.189628</td>
#       <td>0.679922</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.341900</td>
#       <td>1.346701</td>
#       <td>0.688652</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.193000</td>
#       <td>1.371629</td>
#       <td>0.683802</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.193000</td>
#       <td>1.474152</td>
#       <td>0.680892</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.148500</td>
#       <td>1.512132</td>
#       <td>0.686712</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.148500</td>
#       <td>1.566964</td>
#       <td>0.681862</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.148500</td>
#       <td>1.559276</td>
#       <td>0.686712</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.118500</td>
#       <td>1.645460</td>
#       <td>0.680892</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.118500</td>
#       <td>1.641725</td>
#       <td>0.687682</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.107700</td>
#       <td>1.639858</td>
#       <td>0.686712</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-204
# Configuration saved in finetuned_bert-base-uncased/checkpoint-204/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-204/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-204/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-204/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-408
# Configuration saved in finetuned_bert-base-uncased/checkpoint-408/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-408/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-408/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-408/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-612
# Configuration saved in finetuned_bert-base-uncased/checkpoint-612/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-612/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-612/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-612/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-816
# Configuration saved in finetuned_bert-base-uncased/checkpoint-816/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-816/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-816/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-816/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-1020
# Configuration saved in finetuned_bert-base-uncased/checkpoint-1020/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-1020/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-1020/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-1020/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-1224
# Configuration saved in finetuned_bert-base-uncased/checkpoint-1224/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-1224/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-1224/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-1224/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-1428
# Configuration saved in finetuned_bert-base-uncased/checkpoint-1428/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-1428/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-1428/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-1428/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-1632
# Configuration saved in finetuned_bert-base-uncased/checkpoint-1632/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-1632/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-1632/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-1632/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-1836
# Configuration saved in finetuned_bert-base-uncased/checkpoint-1836/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-1836/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-1836/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-1836/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-2040
# Configuration saved in finetuned_bert-base-uncased/checkpoint-2040/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-2040/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-2040/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-2040/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-2244
# Configuration saved in finetuned_bert-base-uncased/checkpoint-2244/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-2244/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-2244/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-2244/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-2448
# Configuration saved in finetuned_bert-base-uncased/checkpoint-2448/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-2448/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-2448/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-2448/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-2652
# Configuration saved in finetuned_bert-base-uncased/checkpoint-2652/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-2652/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-2652/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-2652/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-2856
# Configuration saved in finetuned_bert-base-uncased/checkpoint-2856/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-2856/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-2856/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-2856/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 16
# Saving model checkpoint to finetuned_bert-base-uncased/checkpoint-3060
# Configuration saved in finetuned_bert-base-uncased/checkpoint-3060/config.json
# Model weights saved in finetuned_bert-base-uncased/checkpoint-3060/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/checkpoint-3060/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/checkpoint-3060/special_tokens_map.json
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from finetuned_bert-base-uncased/checkpoint-408 (score: 0.8898962736129761).
# TrainOutput(global_step=3060, training_loss=0.28891910961250855, metrics={'train_runtime': 967.2714, 'train_samples_per_second': 50.539, 'train_steps_per_second': 3.164, 'total_flos': 1205495780390304.0, 'train_loss': 0.28891910961250855, 'epoch': 15.0})

# %%
trainer.evaluate(tokenized_dataset['Session5'])
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1241
#   Batch size = 16
#     <div>
#
#       <progress value='78' max='78' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [78/78 00:03]
#     </div>
# {'eval_loss': 0.9064109325408936,
#  'eval_accuracy': 0.6591458501208702,
#  'eval_runtime': 3.934,
#  'eval_samples_per_second': 315.458,
#  'eval_steps_per_second': 19.827,
#  'epoch': 15.0}

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to finetuned_bert-base-uncased
# Configuration saved in finetuned_bert-base-uncased/config.json
# Model weights saved in finetuned_bert-base-uncased/pytorch_model.bin
# tokenizer config file saved in finetuned_bert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_bert-base-uncased/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/418M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/minoosh/finetuned_bert-base-uncased
#    e80270c..1ccd26a  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/minoosh/finetuned_bert-base-uncased
#    e80270c..1ccd26a  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Text Classification', 'type': 'text-classification'}, 'metrics': [{'name': 'Accuracy', 'type': 'accuracy', 'value': 0.6591458501208702}]}
# To https://huggingface.co/minoosh/finetuned_bert-base-uncased
#    1ccd26a..4ca61f6  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/minoosh/finetuned_bert-base-uncased
#    1ccd26a..4ca61f6  main -> main
# 'https://huggingface.co/minoosh/finetuned_bert-base-uncased/commit/1ccd26a9387ca10a77e55f511e981faadfc4e817'

# %%
############
#Inference

# %%
#text = "This was a masterpiece. Not completely faithful to the books, but enthralling from beginning to end. Might be my favorite of the three."

# %%
'''from transformers import pipeline

classifier = pipeline(model="minoosh/my_first_model")
classifier(text)'''
# Out:
# 'from transformers import pipeline\n\nclassifier = pipeline(model="minoosh/my_first_model")\nclassifier(text)'
