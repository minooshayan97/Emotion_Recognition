# %%
model_ckp = "distilbert-base-uncased"
batch_size = 32

# %%
# !pip install transformers datasets evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 58.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 35.6 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 94.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.4)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 17.9 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 26.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2023.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: tokenizers, xxhash, dill, responses, multiprocess, huggingface-hub, transformers, datasets, evaluate
# Successfully installed datasets-2.10.1 dill-0.3.6 evaluate-0.4.0 huggingface-hub-0.12.1 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.26.1 xxhash-3.2.0

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.10-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.25.1)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (8.1.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.16.0-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=93ba19aca985c57a9b065429c6860448c76d0e40011e8e3f0155af12bf93c317
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.16.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.10

# %%
import wandb
wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset

dataset = load_dataset("minoosh/IEMOCAP_Text")
# Out:
# Downloading readme:   0%|          | 0.00/753 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/minoosh___parquet/minoosh--IEMOCAP_Text-8b3962ea9075930e/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/44.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/39.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/51.9k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating Session2 split:   0%|          | 0/1023 [00:00<?, ? examples/s]
# Generating Session3 split:   0%|          | 0/1151 [00:00<?, ? examples/s]
# Generating Session1 split:   0%|          | 0/1085 [00:00<?, ? examples/s]
# Generating Session4 split:   0%|          | 0/1031 [00:00<?, ? examples/s]
# Generating Session5 split:   0%|          | 0/1241 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/minoosh___parquet/minoosh--IEMOCAP_Text-8b3962ea9075930e/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     Session2: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1023
#     })
#     Session3: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1151
#     })
#     Session1: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1085
#     })
#     Session4: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1031
#     })
#     Session5: Dataset({
#         features: ['emotion', 'transcription'],
#         num_rows: 1241
#     })
# })

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_ckp)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
    return tokenizer(examples["transcription"], truncation=True)

# %%
tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/1023 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1151 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1085 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1031 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1241 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
import evaluate

accuracy = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
import numpy as np

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
dataset = dataset.rename_column("emotion", "label")

# %%
labels = dataset["Session1"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

id2label["1"]
# Out:
# 'hap'

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained(
    model_ckp, num_labels=4, id2label=id2label, label2id=label2id
)
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenized_dataset = tokenized_dataset.rename_column("emotion", "label")

# %%
import torch
train_dataset = torch.utils.data.ConcatDataset([tokenized_dataset['Session1'], tokenized_dataset['Session2'], tokenized_dataset['Session3']])

# %%
train_dataset

# %%
'''splited_tokenized_dataset = tokenized_dataset['train'].train_test_split(test_size=0.2)
splited_tokenized_dataset'''
# Out:
# "splited_tokenized_dataset = tokenized_dataset['train'].train_test_split(test_size=0.2)\nsplited_tokenized_dataset"

# %%
training_args = TrainingArguments(
    output_dir="finetuned_distilbert-base-uncased",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    logging_steps=10,
    num_train_epochs=20,
    weight_decay=0.01,
    warmup_ratio=0.1,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    push_to_hub=True,
    report_to='wandb',
    run_name='finetune_distilbert_base_on_IEMOCAP_text'
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=tokenized_dataset["Session4"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# Cloning https://huggingface.co/minoosh/finetuned_distilbert-base-uncased into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/minoosh/finetuned_distilbert-base-uncased into local empty directory.
# Download file pytorch_model.bin:   0%|          | 1.41k/255M [00:00<?, ?B/s]
# Download file training_args.bin: 100%|##########| 3.50k/3.50k [00:00<?, ?B/s]
# Clean file training_args.bin:  29%|##8       | 1.00k/3.50k [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/255M [00:00<?, ?B/s]

# %%
import torch
torch.cuda.empty_cache()

# %%
results = trainer.train()
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3259
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2040
#   Number of trainable parameters = 66956548
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: minooshayan97 (minoosh). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230305_132813-3dqtadi0</code>
# Syncing run <strong><a href='https://wandb.ai/minoosh/huggingface/runs/3dqtadi0' target="_blank">finetune_distilbert_base_on_IEMOCAP_text</a></strong> to <a href='https://wandb.ai/minoosh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/minoosh/huggingface' target="_blank">https://wandb.ai/minoosh/huggingface</a>
#  View run at <a href='https://wandb.ai/minoosh/huggingface/runs/3dqtadi0' target="_blank">https://wandb.ai/minoosh/huggingface/runs/3dqtadi0</a>
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2040' max='2040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2040/2040 11:55, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.312000</td>
#       <td>1.300974</td>
#       <td>0.449079</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.964100</td>
#       <td>1.042575</td>
#       <td>0.584869</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.716900</td>
#       <td>0.969122</td>
#       <td>0.614937</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.566900</td>
#       <td>0.939579</td>
#       <td>0.645005</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.484400</td>
#       <td>0.964827</td>
#       <td>0.652764</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.377700</td>
#       <td>1.051391</td>
#       <td>0.644035</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.221300</td>
#       <td>1.153146</td>
#       <td>0.633366</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.240400</td>
#       <td>1.272219</td>
#       <td>0.620757</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.248900</td>
#       <td>1.287897</td>
#       <td>0.640155</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.187400</td>
#       <td>1.307218</td>
#       <td>0.645005</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.149500</td>
#       <td>1.368303</td>
#       <td>0.642095</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.141700</td>
#       <td>1.380319</td>
#       <td>0.637245</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.141000</td>
#       <td>1.459209</td>
#       <td>0.630456</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.109200</td>
#       <td>1.510717</td>
#       <td>0.629486</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.120500</td>
#       <td>1.526338</td>
#       <td>0.633366</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.160700</td>
#       <td>1.596266</td>
#       <td>0.618817</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.127000</td>
#       <td>1.569088</td>
#       <td>0.635306</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.135800</td>
#       <td>1.557376</td>
#       <td>0.642095</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.119200</td>
#       <td>1.571302</td>
#       <td>0.642095</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.089800</td>
#       <td>1.573344</td>
#       <td>0.647915</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-102
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-102/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-102/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-102/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-102/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-204
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-204/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-204/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-204/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-204/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-306
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-306/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-306/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-306/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-306/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-408
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-408/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-408/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-408/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-408/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-510
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-510/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-510/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-510/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-510/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-612
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-612/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-612/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-612/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-612/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-714
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-714/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-714/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-714/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-714/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-816
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-816/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-816/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-816/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-816/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-918
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-918/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-918/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-918/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-918/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1020
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1020/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1020/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1020/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1020/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1122
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1122/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1122/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1122/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1122/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1224
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1224/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1224/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1224/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1224/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1326
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1326/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1326/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1326/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1326/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1428
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1428/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1428/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1428/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1428/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1530
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1530/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1530/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1530/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1530/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1632
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1632/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1632/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1632/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1632/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1734
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1734/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1734/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1734/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1734/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1836
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1836/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1836/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1836/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1836/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-1938
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-1938/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-1938/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-1938/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-1938/special_tokens_map.json
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1031
#   Batch size = 32
# Saving model checkpoint to finetuned_distilbert-base-uncased/checkpoint-2040
# Configuration saved in finetuned_distilbert-base-uncased/checkpoint-2040/config.json
# Model weights saved in finetuned_distilbert-base-uncased/checkpoint-2040/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/checkpoint-2040/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/checkpoint-2040/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from finetuned_distilbert-base-uncased/checkpoint-510 (score: 0.6527643064985451).

# %%
trainer.evaluate(tokenized_dataset['Session5'])
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: transcription. If transcription are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1241
#   Batch size = 32
#     <div>
#
#       <progress value='39' max='39' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [39/39 00:02]
#     </div>
# {'eval_loss': 0.9130979180335999,
#  'eval_accuracy': 0.6526994359387591,
#  'eval_runtime': 2.2234,
#  'eval_samples_per_second': 558.155,
#  'eval_steps_per_second': 17.541,
#  'epoch': 20.0}

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to finetuned_distilbert-base-uncased
# Configuration saved in finetuned_distilbert-base-uncased/config.json
# Model weights saved in finetuned_distilbert-base-uncased/pytorch_model.bin
# tokenizer config file saved in finetuned_distilbert-base-uncased/tokenizer_config.json
# Special tokens file saved in finetuned_distilbert-base-uncased/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/minoosh/finetuned_distilbert-base-uncased
#    a267100..26512e8  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/minoosh/finetuned_distilbert-base-uncased
#    a267100..26512e8  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Text Classification', 'type': 'text-classification'}, 'metrics': [{'name': 'Accuracy', 'type': 'accuracy', 'value': 0.6526994359387591}]}
# To https://huggingface.co/minoosh/finetuned_distilbert-base-uncased
#    26512e8..3b6d220  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/minoosh/finetuned_distilbert-base-uncased
#    26512e8..3b6d220  main -> main
# 'https://huggingface.co/minoosh/finetuned_distilbert-base-uncased/commit/26512e8e48bd837fdfa78cff3281c458544306c8'

# %%
############
#Inference

# %%
#text = "This was a masterpiece. Not completely faithful to the books, but enthralling from beginning to end. Might be my favorite of the three."

# %%
'''from transformers import pipeline

classifier = pipeline(model="minoosh/my_first_model")
classifier(text)'''
# Out:
# 'from transformers import pipeline\n\nclassifier = pipeline(model="minoosh/my_first_model")\nclassifier(text)'
